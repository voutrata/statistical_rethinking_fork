# %%
import pymc as pm, polars as pl
import matplotlib.pyplot as plt, numpy as np
import arviz as az
import seaborn as sns

# %%
d = pl.read_csv("../../Rethinking_2/Data/Howell1.csv", separator=";")
df = d.select("height", "weight", "age")

# %%
df = df.with_columns(
    age=pl.min(pl.lit(18), pl.col("age")),
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 df = df.with_columns(
# ----> 2     age=pl.min(pl.lit(18), pl.col("age")),
#       3 )
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/polars/functions/aggregation/vertical.py:236, in min(*names)
#     179 def min(*names: str) -> Expr:
#     180     """
#     181     Get the minimum value.
#     182
#    (...)
#     234     └─────┴─────┘
#     235     """
# --> 236     return F.col(*names).min()
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/polars/functions/col.py:329, in Col.__call__(self, name, *more_names)
#     176 def __call__(
#     177     self,
#     178     name: (
#    (...)
#     185     *more_names: str | PolarsDataType | PythonDataType,
#     186 ) -> Expr:
#     187     """
#     188     Create one or more expressions representing columns in a DataFrame.
#     189
#    (...)
#     327     └─────┴───────────┴─────┘
#     328     """
# --> 329     return _create_col(name, *more_names)
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/polars/functions/col.py:57, in _create_col(name, *more_names)
#      52     else:
#      53         msg = (
#      54             "invalid input for `col`"
#      55             f"\n\nExpected `str` or `DataType`, got {type(name).__name__!r}."
#      56         )
# ---> 57         raise TypeError(msg)
#      59 if isinstance(name, str):
#      60     return wrap_expr(plr.col(name))
#
# TypeError: invalid input for `col`
#
# Expected `str` or `DataType`, got 'Expr'.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
sns.scatterplot(
    df,
    x="weight",
    y="height",
    hue="age",
    ax=ax,
)
ax.set_xlabel('weight')
ax.set_ylabel('height')

# %%
df.max()
# Out:
# shape: (1, 3)
# ┌────────┬───────────┬──────┐
# │ height ┆ weight    ┆ age  │
# │ ---    ┆ ---       ┆ ---  │
# │ f64    ┆ f64       ┆ f64  │
# ╞════════╪═══════════╪══════╡
# │ 179.07 ┆ 62.992589 ┆ 88.0 │
# └────────┴───────────┴──────┘

# %%
# model definition
with pm.Model() as basic_model:
    # priors
    alpha = pm.Normal(name="alpha", mu=50, sigma=5)
    beta = pm.Normal(name="beta", mu=3, sigma=1)
    sigma = pm.Uniform(name="sigma", lower=0, upper=20)

    weight = pm.MutableData("weight", df["weight"].to_numpy())

    mu = alpha + beta*weight

    height = pm.Normal("height", mu=mu, sigma=sigma, observed=df["height"].to_numpy())

    # check prior predictive
    basic_prior_predictive = pm.sample_prior_predictive(draws=500)

    # compute posterior
    basic_posterior_distribution = pm.sample(draws=752)

    # compute posterior predictive
    basic_posterior_predictive = pm.sample_posterior_predictive(basic_posterior_distribution)

    # compute likelihood
    pm.compute_log_likelihood(basic_posterior_distribution)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
az.plot_density()

# %%
# model definition
with pm.Model() as interaction_model:
    # priors
    alpha = pm.Normal(name="alpha", mu=50, sigma=5)
    beta = pm.Normal(name="beta", mu=3, sigma=1)
    beta_interaction = pm.Normal(name="beta_interaction", mu=0, sigma=0.2)
    sigma = pm.Uniform(name="sigma", lower=0, upper=20)

    weight = pm.MutableData("weight", df["weight"].to_numpy())

    mu = alpha + beta*weight + beta_interaction*(df["weight"]*df["age"]).to_numpy()

    height = pm.Normal("height", mu=mu, sigma=sigma, observed=df["height"].to_numpy())

    # check prior predictive
    interaction_prior_predictive = pm.sample_prior_predictive(draws=500)

    # compute posterior
    interaction_posterior_distribution = pm.sample(draws=752)

    # compute posterior predictive
    interaction_posterior_predictive = pm.sample_posterior_predictive(interaction_posterior_distribution)

    # compute likelihood
    pm.compute_log_likelihood(interaction_posterior_distribution)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# model definition
with pm.Model(coords={"age": np.arange(18)}) as dirichlet_model:

    alpha_intercept = pm.Normal("alpha", 50, 5)
    gamma = pm.Normal("gamma", 2, 1)
    gamma_interaction = pm.Normal("gamma_interaction", 0, 1)
    sigma = pm.Uniform("sigma", 0, 20)

    K = 18

    alpha_dirichlet = 0.2 * np.ones(K)
    delta = pm.Dirichlet("delta", a=alpha_dirichlet, dims="age")

    raw_multiplier = pm.math.cumsum(delta)

    age_multiplier = pm.Deterministic(
        "age_multiplier",
        gamma - gamma_interaction*raw_multiplier,
        dims="age"
    )

    weight = pm.MutableData("weight", df["weight"].to_numpy())
    age_idx = pm.Data("age_idx", df["age"].to_numpy().astype("int64")-1)

    mu = alpha_intercept + weight * age_multiplier[age_idx]


    height = pm.Normal("height", mu=mu, sigma=sigma, observed=df["height"].to_numpy())


    # check prior predictive
    dirichlet_prior_predictive = pm.sample_prior_predictive(draws=200)

    # compute posterior
    dirichlet_posterior_distribution = pm.sample(draws=500)

    # compute posterior predictive
    dirichlet_posterior_predictive = pm.sample_posterior_predictive(dirichlet_posterior_distribution)

    # compute likelihood
    pm.compute_log_likelihood(dirichlet_posterior_distribution)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pytensor/compile/function/types.py:1039, in Function.__call__(self, output_subset, *args, **kwargs)
#    1038 try:
# -> 1039     outputs = vm() if output_subset is None else vm(output_subset=output_subset)
#    1040 except Exception:
#
# IndexError: index 62 is out of bounds for axis 0 with size 18
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 31
#      27 height = pm.Normal("height", mu=mu, sigma=sigma, observed=df["height"].to_numpy())
#      30 # check prior predictive
# ---> 31 dirichlet_prior_predictive = pm.sample_prior_predictive(draws=200)
#      33 # compute posterior
#      34 dirichlet_posterior_distribution = pm.sample(draws=500)
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pymc/sampling/forward.py:477, in sample_prior_predictive(draws, model, var_names, random_seed, return_inferencedata, idata_kwargs, compile_kwargs, samples)
#     475 # All model variables have a name, but mypy does not know this
#     476 _log.info(f"Sampling: {sorted(volatile_basic_rvs, key=lambda var: var.name)}")  # type: ignore[arg-type, return-value]
# --> 477 values = zip(*(sampler_fn() for i in range(draws)))
#     479 data = {k: np.stack(v) for k, v in zip(names, values)}
#     480 if data is None:
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pymc/sampling/forward.py:477, in <genexpr>(.0)
#     475 # All model variables have a name, but mypy does not know this
#     476 _log.info(f"Sampling: {sorted(volatile_basic_rvs, key=lambda var: var.name)}")  # type: ignore[arg-type, return-value]
# --> 477 values = zip(*(sampler_fn() for i in range(draws)))
#     479 data = {k: np.stack(v) for k, v in zip(names, values)}
#     480 if data is None:
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pytensor/compile/function/types.py:1049, in Function.__call__(self, output_subset, *args, **kwargs)
#    1047     if hasattr(self.vm, "thunks"):
#    1048         thunk = self.vm.thunks[self.vm.position_of_error]
# -> 1049     raise_with_op(
#    1050         self.maker.fgraph,
#    1051         node=self.vm.nodes[self.vm.position_of_error],
#    1052         thunk=thunk,
#    1053         storage_map=getattr(self.vm, "storage_map", None),
#    1054     )
#    1055 else:
#    1056     # old-style linkers raise their own exceptions
#    1057     raise
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pytensor/link/utils.py:526, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     521     warnings.warn(
#     522         f"{exc_type} error does not allow us to add an extra error message"
#     523     )
#     524     # Some exception need extra parameter in inputs. So forget the
#     525     # extra long error message in that case.
# --> 526 raise exc_value.with_traceback(exc_trace)
#
# File ~/Projects/pymc-resources/.venv/lib/python3.10/site-packages/pytensor/compile/function/types.py:1039, in Function.__call__(self, output_subset, *args, **kwargs)
#    1037     t0_fn = time.perf_counter()
#    1038 try:
# -> 1039     outputs = vm() if output_subset is None else vm(output_subset=output_subset)
#    1040 except Exception:
#    1041     self._restore_defaults()
#
# IndexError: index 62 is out of bounds for axis 0 with size 18
# Apply node that caused the error: AdvancedSubtensor1(age_multiplier, age_idx)
# Toposort index: 10
# Inputs types: [TensorType(float64, shape=(None,)), TensorType(int32, shape=(None,))]
# Inputs shapes: [(18,), (544,)]
# Inputs strides: [(8,), (4,)]
# Inputs values: ['not shown', 'not shown']
# Outputs clients: [[Composite{(i2 + (i0 * i1))}(weight, AdvancedSubtensor1.0, ExpandDims{axis=0}.0)]]
#
# Backtrace when the node is created (use PyTensor flag traceback__limit=N to make it longer):
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/voutrata/Projects/pymc-resources/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/3g/qw0kh7k15n90fnk3l1jxy2d80000gn/T/ipykernel_99384/675740026.py", line 24, in <module>
#     mu = alpha_intercept + weight * age_multiplier[age_idx]
#
# HINT: Use the PyTensor flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
az.summary(basic_posterior_distribution)
# Out:
#          mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# alpha  68.172  1.333  65.728   70.710      0.035    0.025    1483.0    1620.0
# beta    2.064  0.048   1.975    2.152      0.001    0.001    1455.0    1473.0
# sigma  10.781  0.491   9.914   11.703      0.012    0.011    1817.0    1716.0
#
#        r_hat
# alpha    1.0
# beta     1.0
# sigma    1.0

# %%
az.plot_trace(basic_posterior_distribution)

# %%
az.plot_trace(interaction_posterior_distribution)

# %%
az.plot_trace(dirichlet_posterior_distribution)

# %%
az.plot_forest(
    dirichlet_posterior_distribution,
    var_names=["delta", "age_multiplier"],
    combined=True,
    hdi_prob=0.94
)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Prior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[0]
)
az.plot_hdi(
    basic_prior_predictive.constant_data.weight,
    basic_prior_predictive.prior_predictive.height,
    ax=axes[0]
)
axes[0].set_title("Prior Predictive")
axes[0].set_xlabel("weight")
axes[0].set_ylabel("height")

# Posterior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[1]
)
az.plot_hdi(
    basic_posterior_predictive.constant_data.weight,
    basic_posterior_predictive.posterior_predictive.height,
    ax=axes[1]
)
axes[1].set_title("Posterior Predictive")
axes[1].set_xlabel("weight")

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Prior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[0]
)
az.plot_hdi(
    interaction_prior_predictive.constant_data.weight,
    interaction_prior_predictive.prior_predictive.height,
    ax=axes[0]
)
axes[0].set_title("Prior Predictive")
axes[0].set_xlabel("weight")
axes[0].set_ylabel("height")

# Posterior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[1]
)
az.plot_hdi(
    interaction_posterior_predictive.constant_data.weight,
    interaction_posterior_predictive.posterior_predictive.height,
    ax=axes[1]
)
axes[1].set_title("Posterior Predictive")
axes[1].set_xlabel("weight")

plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Prior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[0]
)
az.plot_hdi(
    dirichlet_prior_predictive.constant_data.weight,
    dirichlet_prior_predictive.prior_predictive.height,
    ax=axes[0]
)
axes[0].set_title("Prior Predictive")
axes[0].set_xlabel("weight")
axes[0].set_ylabel("height")

# Posterior predictive
az.plot_pair(
    df.select("weight", "height").to_dict(),
    ax=axes[1]
)
az.plot_hdi(
    dirichlet_posterior_predictive.constant_data.weight,
    dirichlet_posterior_predictive.posterior_predictive.height,
    ax=axes[1]
)
axes[1].set_title("Posterior Predictive")
axes[1].set_xlabel("weight")

plt.tight_layout()

# %%
comparison = az.compare({
    "basic": basic_posterior_distribution,
    "interaction": interaction_posterior_distribution,
    "dirichlet": dirichlet_posterior_distribution,
}, scale="deviance")
comparison
# Out:
#              rank     elpd_loo     p_loo   elpd_diff        weight         se  \
# dirichlet       0  1744.372829  7.736074    0.000000  9.463337e-01  25.354740
# interaction     1  1866.193301  3.831565  121.820472  5.907271e-14  19.723302
# basic           2  1892.356720  2.994396  147.983891  5.366634e-02  18.093184
#
#                    dse  warning     scale
# dirichlet     0.000000    False  deviance
# interaction  17.537937    False  deviance
# basic        22.967552    False  deviance

# %%
az.plot_compare(comparison, insample_dev=True, plot_ic_diff=True)
